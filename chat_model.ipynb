# %%
from dotenv import load_dotenv, find_dotenv
import os

# %%
env_path = find_dotenv()
load_dotenv(env_path, override=True)
# Out:
# True

# %%
print(f"Key loaded: {os.environ.get('OPENAI_API_KEY')[:20]}...")
# Out:
# Key loaded: sk-proj-HgeMAxXfyAWH...

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("gpt-4.1")
response = model.invoke("What is capital of chile?")
response
# Out:
# AIMessage(content='The capital of Chile is **Santiago**.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 13, 'total_tokens': 23, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-2025-04-14', 'system_fingerprint': 'fp_aae4b5f0e2', 'id': 'chatcmpl-DJb6DU8gAnGEnsq43N0gNEtkt5zL6', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cf09a-f9db-7dd3-aba2-d0093b065376-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 10, 'total_tokens': 23, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_openai import ChatOpenAI

direct_model = ChatOpenAI(model="gpt-4.1")
response = direct_model.invoke("What is capital of chile?")
response
# Out:
# AIMessage(content='The capital of Chile is **Santiago**.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 13, 'total_tokens': 23, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-2025-04-14', 'system_fingerprint': 'fp_aae4b5f0e2', 'id': 'chatcmpl-DJb6Rs8x3ZyZfCovmIxAfkzaQGxNH', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cf09b-310c-7a93-89f0-31c839018780-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 10, 'total_tokens': 23, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
# temperature=0.7,
# timeout=30,
# max_tokens=1000,
# max_retries=6

# %%
for chunk in model.stream("Why do parrots have colorful feathers?"):
    print(chunk.text, end="|", flush=True)
# Out:
# |Par|rots| have| colorful| feathers| for| several| reasons|,| related| to| their| survival| and| behavior|:
#
# |1|.| **|Species| and| Mate| Recognition|:**| Bright| feather| colors| help| parro|ts| recognize| and| find| others| of| their| own| species|,| especially| in| environments| where| many| species| live| close| together|.
#
# |2|.| **|At|tract|ing| M|ates|:**| Many| par|rot| species| use| their| vibrant| colors| to| attract| mates|.| Bright|,| healthy| feathers| can| signal| good| health| and| genetic| quality| to| potential| partners|.
#
# |3|.| **|Cam|ouflage|:**| Although| it| might| seem| counter|int|uitive|,| brightly| colored| feathers| can| help| parro|ts| blend| into| their| natural| habitats|.| Many| parro|ts| live| in| rain|fore|sts| filled| with| colorful| flowers|,| fruits|,| and| d|apple|d| sunlight|,| where| their| plum|age| helps| them| remain| concealed| from| predators|.
#
# ...

# %%
responses = model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
])
for response in responses:
    print(response)
# Out:
# content='Parrots have colorful feathers due to a combination of evolutionary, biological, and ecological reasons:\n\n**1. Camouflage:**  \nDespite appearing brightly colored to humans, a parrot’s feathers can help it blend into its natural environment. Many parrots live in rainforests filled with vibrant foliage, flowers, and fruits. Their green, red, yellow, and blue feathers provide camouflage among the leaves, fruits, and flowers.\n\n**2. Communication:**  \nBright feathers play a role in social signaling. Parrots use their colors to recognize each other, attract mates, and display health or maturity. For example, more vivid coloring may signal a healthy, genetically fit individual to potential mates.\n\n**3. Species and Individual Recognition:**  \nColor patterns help parrots distinguish between species, as well as individuals within a group. This is important for maintaining flocks and social structure.\n\n**4. Warning or Threat Display:**  \nIn some cases, bright colors can ser
# ...

# %%
for response in model.batch_as_completed([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
]):
    print(response)

# %%
from pydantic import BaseModel,  Field

class Movie(BaseModel):
    title: str = Field(description="The title of the movie")
    year: int = Field(description="The year the movie was released")
    director: str = Field(description= "The director of the movie")
    rating: float = Field(description= "The movie rating out of 10")

model_with_structure = model.with_structured_output(Movie)
response = model_with_structure.invoke("Provide deatils about the movie Inception")
response
